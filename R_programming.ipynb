# %% [markdown]
# <a href="https://colab.research.google.com/github/ganesaperumal03/data-analysis-using-R-/blob/main/R_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(readr)
# data = read.csv("/content/drive/MyDrive/assigments/Pokemon (1).csv")
# print(data)
# Out:
#      X.                      Name   Type.1   Type.2 Total  HP Attack Defense
# 1     1                 Bulbasaur    Grass   Poison   318  45     49      49
# 2     2                   Ivysaur    Grass   Poison   405  60     62      63
# 3     3                  Venusaur    Grass   Poison   525  80     82      83
# 4     3     VenusaurMega Venusaur    Grass   Poison   625  80    100     123
# 5     4                Charmander     Fire            309  39     52      43
# 6     5                Charmeleon     Fire            405  58     64      58
# 7     6                 Charizard     Fire   Flying   534  78     84      78
# 8     6 CharizardMega Charizard X     Fire   Dragon   634  78    130     111
# 9     6 CharizardMega Charizard Y     Fire   Flying   634  78    104      78
# 10    7                  Squirtle    Water            314  44     48      65
# 11    8                 Wartortle    Water            405  59     63      80
# ...

# %%
# %%R
# head(data)
# Out:
#   X.                  Name Type.1 Type.2 Total HP Attack Defense Sp..Atk
# 1  1             Bulbasaur  Grass Poison   318 45     49      49      65
# 2  2               Ivysaur  Grass Poison   405 60     62      63      80
# 3  3              Venusaur  Grass Poison   525 80     82      83     100
# 4  3 VenusaurMega Venusaur  Grass Poison   625 80    100     123     122
# 5  4            Charmander   Fire          309 39     52      43      60
# 6  5            Charmeleon   Fire          405 58     64      58      80
#   Sp..Def Speed Generation Legendary
# 1      65    45          1     False
# 2      80    60          1     False
# 3     100    80          1     False
# 4     120    80          1     False
# 5      50    65          1     False
# 6      65    80          1     False

# %%
# %%R
# summary(data)
# Out:
#        X.            Name              Type.1             Type.2
#  Min.   :  1.0   Length:800         Length:800         Length:800
#  1st Qu.:184.8   Class :character   Class :character   Class :character
#  Median :364.5   Mode  :character   Mode  :character   Mode  :character
#  Mean   :362.8
#  3rd Qu.:539.2
#  Max.   :721.0
#      Total             HP             Attack       Defense
#  Min.   :180.0   Min.   :  1.00   Min.   :  5   Min.   :  5.00
#  1st Qu.:330.0   1st Qu.: 50.00   1st Qu.: 55   1st Qu.: 50.00
#  Median :450.0   Median : 65.00   Median : 75   Median : 70.00
#  Mean   :435.1   Mean   : 69.26   Mean   : 79   Mean   : 73.84
#  3rd Qu.:515.0   3rd Qu.: 80.00   3rd Qu.:100   3rd Qu.: 90.00
#  Max.   :780.0   Max.   :255.00   Max.   :190   Max.   :230.00
#     Sp..Atk          Sp..Def          Speed          Generation
#  Min.   : 10.00   Min.   : 20.0   Min.   :  5.00   Min.   :1.000
#  1st Qu.: 49.75   1st Qu.: 50.0   1st Qu.: 45.00   1st Qu.:2.000
# ...

# %%
# %%R
# nrow(data)
# Out:
# [1] 800

# %%
# %%R
# ncol(data)
# Out:
# [1] 13

# %%
# %%R
# sum(is.na(data))
# Out:
# [1] 0

# %%
# %%R
# colnames(data)
# Out:
#  [1] "X."         "Name"       "Type.1"     "Type.2"     "Total"
#  [6] "HP"         "Attack"     "Defense"    "Sp..Atk"    "Sp..Def"
# [11] "Speed"      "Generation" "Legendary"

# %%
# %%R
# library(dplyr)
# data %>% filter(Type.1=="Grass") -> grass_pokemon
# grass_pokemon
# Out:
#     X.                    Name Type.1   Type.2 Total  HP Attack Defense Sp..Atk
# 1    1               Bulbasaur  Grass   Poison   318  45     49      49      65
# 2    2                 Ivysaur  Grass   Poison   405  60     62      63      80
# 3    3                Venusaur  Grass   Poison   525  80     82      83     100
# 4    3   VenusaurMega Venusaur  Grass   Poison   625  80    100     123     122
# 5   43                  Oddish  Grass   Poison   320  45     50      55      75
# 6   44                   Gloom  Grass   Poison   395  60     65      70      85
# 7   45               Vileplume  Grass   Poison   490  75     80      85     110
# 8   69              Bellsprout  Grass   Poison   300  50     75      35      70
# 9   70              Weepinbell  Grass   Poison   390  65     90      50      85
# 10  71              Victreebel  Grass   Poison   490  80    105      65     100
# 11 102               Exeggcute  Grass  Psychic   325  60     40      80      60
# ...

# %%
# %%R
# count(grass_pokemon)
# Out:
#    n
# 1 70

# %%
# %%R
# grass_pokemon %>% filter(Name =='ShayminSky Forme ') -> x
# x
# Out:
#  [1] X.         Name       Type.1     Type.2     Total      HP
#  [7] Attack     Defense    Sp..Atk    Sp..Def    Speed      Generation
# [13] Legendary
# <0 rows> (or 0-length row.names)

# %%
# %%R
# grass_pokemon %>% filter(Name =='ShayminSky Forme ') -> x
# x
# Out:
#  [1] X.         Name       Type.1     Type.2     Total      HP
#  [7] Attack     Defense    Sp..Atk    Sp..Def    Speed      Generation
# [13] Legendary
# <0 rows> (or 0-length row.names)

# %%
# %%R
# grass_pokemon %>% filter(Speed =='113') -> x
# x
# Out:
#    X.      Name Type.1 Type.2 Total HP Attack Defense Sp..Atk Sp..Def Speed
# 1 497 Serperior  Grass          528 75     75      95      75      95   113
#   Generation Legendary
# 1          5     False

# %%
# %%R
# library(ggplot2)
# ggplot(data = grass_pokemon,aes(x=HP)) + geom_histogram()
# ggplot(data = grass_pokemon,aes(x=HP)) + geom_histogram(fill="yellow")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# #legendary vs not-legendary
# ggplot(data = grass_pokemon,aes(x=Legendary)) + geom_bar(fill="green")

# %%
# %%R
# ggplot(data = grass_pokemon,aes(x=Speed)) + geom_histogram(fill='darkred')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# data %>% filter(Type.1=="Fire") -> fire_pokemon
# fire_pokemon
# Out:
#     X.                      Name Type.1   Type.2 Total  HP Attack Defense
# 1    4                Charmander   Fire            309  39     52      43
# 2    5                Charmeleon   Fire            405  58     64      58
# 3    6                 Charizard   Fire   Flying   534  78     84      78
# 4    6 CharizardMega Charizard X   Fire   Dragon   634  78    130     111
# 5    6 CharizardMega Charizard Y   Fire   Flying   634  78    104      78
# 6   37                    Vulpix   Fire            299  38     41      40
# 7   38                 Ninetales   Fire            505  73     76      75
# 8   58                 Growlithe   Fire            350  55     70      45
# 9   59                  Arcanine   Fire            555  90    110      80
# 10  77                    Ponyta   Fire            410  50     85      55
# 11  78                  Rapidash   Fire            500  65    100      70
# 12 126                    Magmar   Fire            495  65     95      57
# ...

# %%
# %%R
# count(fire_pokemon)
# Out:
#    n
# 1 52

# %%
# %%R
# data %>% filter(Name=="Charmander") -> x
# x
# Out:
#   X.       Name Type.1 Type.2 Total HP Attack Defense Sp..Atk Sp..Def Speed
# 1  4 Charmander   Fire          309 39     52      43      60      50    65
#   Generation Legendary
# 1          1     False

# %%
# %%R
# data %>% filter(Speed=="100") -> y
# count(y)
# Out:
#    n
# 1 31

# %%
# %%R
# data %>% filter(Speed=="100") -> y
# count(y)
# Out:
#    n
# 1 31

# %%
# %%R
# ggplot(data = fire_pokemon,aes(x=Defense)) + geom_histogram(fill="yellow")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# #sp_attack vs sp_defense
# ggplot(data = fire_pokemon,aes(x=Sp..Atk,y=Sp..Def)) + geom_point()

# %%
# %%R
# data %>% filter(Type.1=="Water") -> water_pokemon
# water_pokemon
# Out:
#      X.                    Name Type.1   Type.2 Total  HP Attack Defense
# 1     7                Squirtle  Water            314  44     48      65
# 2     8               Wartortle  Water            405  59     63      80
# 3     9               Blastoise  Water            530  79     83     100
# 4     9 BlastoiseMega Blastoise  Water            630  79    103     120
# 5    54                 Psyduck  Water            320  50     52      48
# 6    55                 Golduck  Water            500  80     82      78
# 7    60                 Poliwag  Water            300  40     50      40
# 8    61               Poliwhirl  Water            385  65     65      65
# 9    62               Poliwrath  Water Fighting   510  90     95      95
# 10   72               Tentacool  Water   Poison   335  40     40      35
# 11   73              Tentacruel  Water   Poison   515  80     70      65
# 12   79                Slowpoke  Water  Psychic   315  90     65      65
# ...

# %%
# %%R
# count(water_pokemon)
# Out:
#     n
# 1 112

# %%
# %%R
# data %>% filter(Name=="Suicune") -> x
# x
# Out:
#    X.    Name Type.1 Type.2 Total  HP Attack Defense Sp..Atk Sp..Def Speed
# 1 245 Suicune  Water          580 100     75     115      90     115    85
#   Generation Legendary
# 1          2      True

# %%
# %%R
# data %>% filter(Attack=="105") -> x
# count(x)
# Out:
#    n
# 1 17

# %%
# %%R
# ggplot(data = water_pokemon,aes(x=Speed)) + geom_histogram(fill="blue")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# ggplot(data = water_pokemon,aes(x=Attack)) + geom_histogram(fill='brown')
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# #sp_attack vs sp_defense
# ggplot(data = water_pokemon,aes(x=Sp..Atk,y=Sp..Def)) + geom_point()
